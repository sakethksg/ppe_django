# %%
# %cd /content/drive/MyDrive/training yolo/yolo/construction safety.v2-release.yolov8/
# Out:
# /content/drive/MyDrive/training yolo/yolo/construction safety.v2-release.yolov8

# %%
# !pip install ultralytics --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 kB 50.9 MB/s eta 0:00:00

# %%
# !nvidia-smi
# Out:
# Tue Nov 26 11:22:40 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data="/content/drive/MyDrive/training yolo/yolo/construction safety.v2-release.yolov8/data.yaml" epochs=50 imgsz=640 batch=16
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 6.25M/6.25M [00:00<00:00, 207MB/s]
# Ultralytics 8.3.37 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model="/content/drive/MyDrive/training yolo/yolo/construction safety.v2-release.yolov8/runs/detect/train2/weights/best.pt" source="/content/drive/MyDrive/training yolo/yolo/construction safety.v2-release.yolov8/test/images"
# Out:
# Ultralytics 8.3.37 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/90 /content/drive/MyDrive/training yolo/yolo/construction safety.v2-release.yolov8/test/images/ppe_0000_jpg.rf.c102a9a7c8dec01565a8f95ff295974c.jpg: 448x640 1 helmet, 1 no-vest, 1 person, 1 vest, 38.2ms
# image 2/90 /content/drive/MyDrive/training yolo/yolo/construction safety.v2-release.yolov8/test/images/ppe_0004_jpg.rf.c3265071237f64a4f0c3e1bf3048f923.jpg: 640x640 3 helmets, 2 no-vests, 3 persons, 3 vests, 8.3ms
# image 3/90 /content/drive/MyDrive/training yolo/yolo/construction safety.v2-release.yolov8/test/images/ppe_0008_jpg.rf.356284e8df05dcd239cb91cf53b51c83.jpg: 448x640 1 helmet, 2 no-helmets, 4 persons, 4 vests, 7.5ms
# ...

# %%
# !yolo task=detect mode=predict model="/content/drive/MyDrive/training yolo/yolo/construction safety.v2-release.yolov8/runs/detect/train2/weights/best.pt" source="/content/drive/MyDrive/firstmilestone/videos/video2.mp4"
# Out:
# Ultralytics 8.3.37 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/349) /content/drive/MyDrive/firstmilestone/videos/video2.mp4: 384x640 4 helmets, 1 no-vest, 3 persons, 2 vests, 56.7ms
# video 1/1 (frame 2/349) /content/drive/MyDrive/firstmilestone/videos/video2.mp4: 384x640 4 helmets, 1 no-vest, 3 persons, 2 vests, 11.7ms
# video 1/1 (frame 3/349) /content/drive/MyDrive/firstmilestone/videos/video2.mp4: 384x640 4 helmets, 1 no-vest, 3 persons, 2 vests, 11.0ms
# video 1/1 (frame 4/349) /content/drive/MyDrive/firstmilestone/videos/video2.mp4: 384x640 4 helmets, 1 no-vest, 3 persons, 2 vests, 11.6ms
# video 1/1 (frame 5/349) /content/drive/MyDrive/firstmilestone/videos/video2.mp4: 384x640 4 helmets, 1 no-vest, 3 persons, 2 vests, 12.6ms
# ...
